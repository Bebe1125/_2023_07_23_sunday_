# %%
import os
import csv

root = os.path.abspath('./')
filePath = os.path.join(root,"csv_data","個股日成交資訊.csv")

with open(filePath,encoding='utf-8',newline='') as file:
    csv_reader= csv.reader(file)
    next(csv_reader)
    stock_data = list(csv_reader)
print(stock_data)
print(len(stock_data))
# Out:
# [['0050', '元大台灣50', '46,790,503', '3,463,425,684', '74.95', '75.25', '72.80', '72.80', '-2.05', '23,021'], ['0051', '元大中型100', '43,172', '1,177,199', '27.30', '27.57', '26.75', '26.75', '-0.52', '45'], ['0052', '富邦科技', '161,425', '9,156,750', '57.60', '57.60', '55.35', '55.35', '-2.35', '67'], ['0053', '元大電子', '35,076', '1,163,448', '33.36', '33.61', '32.56', '32.69', '-0.67', '19'], ['0054', '元大台商50', '27,028', '507,569', '18.80', '19.00', '18.64', '18.64', '-0.36', '13'], ['0055', '元大MSCI金融', '62,050', '940,984', '15.35', '15.35', '15.00', '15.10', '-0.32', '52'], ['0056', '元大高股息', '80,530,934', '1,897,973,002', '23.70', '23.82', '23.26', '23.29', '-0.38', '35,938'], ['0057', '富邦摩台', '20,011', '967,537', '48.35', '48.35', '48.35', '48.35', '-0.90', '3'], ['0061', '元大寶滬深', '5,889,414', '103,296,868', '17.30', '18.50', '16.90', '17.93', '+1.00', '2,346'], ['006203', '元大MSCI台灣', '7,000', '242,470', '34.98', '34.98', '34.52', '34.52', '-0.20', '5'], ['006204', '永豐臺灣加權', '7,000', '327,6
# ...

# %%
import os
import csv

root = os.path.abspath('./')
filePath = os.path.join(root,"csv_data","個股日成交資訊.csv")

with open(filePath,encoding='utf-8',newline='') as file:
    csv_dictreader= csv.DictReader(file)
    for item in csv_dictreader:
        print(item['證券名稱'],item['收盤價'])

print(data)
# Out:
# 元大台灣50 72.80
# 元大中型100 26.75
# 富邦科技 55.35
# 元大電子 32.69
# 元大台商50 18.64
# 元大MSCI金融 15.10
# 元大高股息 23.29
# 富邦摩台 48.35
# 元大寶滬深 17.93
# 元大MSCI台灣 34.52
# 永豐臺灣加權 46.63
# 富邦上証 28.22
# 元大上證50 29.24
# FH滬深 21.95
# 富邦台50 41.55
# 富邦上証+R 6.67
# 元大台灣50正2 30.66
# 元大台灣50反1 12.90
# 富邦上証正2 35.89
# 富邦上証反1 6.34
# 元大S&P黃金 21.70
# 國泰中國A50 19.31
# 國泰中國A50+U 0.00
# 元大滬深300正2 13.72
# 元大滬深300反1 12.85
# 富邦深100 10.71
# 富邦日本正2 12.28
# 富邦日本反1 18.03
# 元大S&P石油 10.25
# 群益深証中小 13.02
# 群益深証中小+R 0.00
# 富邦日本 16.79
# 元大S&P500 22.38
# 元大S&P500正2 22.41
# 元大S&P500反1 14.20
# FH香港正2 20.09
# FH香港反1 9.68
# 富邦印度 16.94
# 富邦印度正2 15.20
# 富邦印度反1 17.65
# 國泰中國A50正2 25.90
# 國泰中國A50反1 11.68
# 國泰日經225 20.83
# 國泰日經225+U 7.00
# 元大歐洲50 17.81
# 元大日經225 21.50
# 富邦NASDAQ 27.87
# 國泰臺灣加權正2 27.20
# 國泰臺灣加權反1 14.69
# 富邦恒生國企正2 18.22
# 富邦恒生國企反1 15.15
# 國泰美國道瓊 22.28
# 國泰美國道瓊+U 7.48
# 國泰美國道瓊反1 15.60
# 富邦NASDAQ正2 26.60
# 富邦NASDAQ反1 12.89
# 元大S&P原油正2 2.40
# 元大S&P原油反1 26.06
# 元大S&P黃金反1 16.31
# 富邦臺灣加權正2 11.94
# 富邦臺灣加權反1 7.94
# 富邦VIX 11.30
# 群益NBI生技 19.01
# ...
